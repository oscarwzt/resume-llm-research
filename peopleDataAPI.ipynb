# %%
import requests
from peopledatalabs import PDLPY

# %%
client = PDLPY(
        api_key = 'a5fcad7182d20e9565fad3db1bd360f5055c826edcf9f10cf250e9af4571d514'
)

# %%
query = """SELECT * FROM person 
            WHERE job_title='data scientist' 
            OR job_title='Data Scientist'
            """
params = {
    'sql': query,
    'size': 5,
    'pretty': True
}
data = client.person.search(**params)

# %%
data.json()
# Out:
# {'status': 200,
#  'data': [{'id': 'uAyVatW53ZkcfMvrB1P08g_0000',
#    'full_name': 'william mattull',
#    'first_name': 'william',
#    'middle_initial': 'a',
#    'middle_name': None,
#    'last_initial': 'm',
#    'last_name': 'mattull',
#    'gender': 'male',
#    'birth_year': 1972,
#    'birth_date': '1972-10-24',
#    'linkedin_url': 'linkedin.com/in/williammattull',
#    'linkedin_username': 'williammattull',
#    'linkedin_id': '16379744',
#    'facebook_url': 'facebook.com/williammattull',
#    'facebook_username': 'williammattull',
#    'facebook_id': '685289515',
#    'twitter_url': 'twitter.com/williammattull',
#    'twitter_username': 'williammattull',
#    'github_url': 'github.com/williammattull',
#    'github_username': 'williammattull',
#    'work_email': 'william.mattull@viasat.com',
#    'personal_emails': ['wmattull@gmail.com',
#     'wmattull@hotmail.com',
#     'bmattull@concentric.net'],
#    'recommended_personal_email': 'wmattull@gmail.com',
# ...

# %%
def
